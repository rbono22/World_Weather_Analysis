# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from conf import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
#create a dataframe to store all the cities and countries generated with citipy
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_describe = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rawson
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | erenhot
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | coari
# Processing Record 9 of Set 1 | san eugenio
# Processing Record 10 of Set 1 | basco
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | sassandra
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | labuhan
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | vao
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | istanbul
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | boueni
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | necochea
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | kurilsk
# Processing Record 42 of Set 1 | palestine
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | yumen
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | port moresby
# Processing Record 47 of Set 1 | sayyan
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | palmer
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | yarada
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | yurga
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | ahuimanu
# Processing Record 8 of Set 2 | ilebo
# Processing Record 9 of Set 2 | vangaindrano
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | baykit
# Processing Record 12 of Set 2 | benguela
# Processing Record 13 of Set 2 | idrinskoye
# Processing Record 14 of Set 2 | olinda
# Processing Record 15 of Set 2 | pangnirtung
# Processing Record 16 of Set 2 | lianzhou
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | saint-augustin
# Processing Record 20 of Set 2 | bac lieu
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | nynashamn
# Processing Record 23 of Set 2 | carballo
# Processing Record 24 of Set 2 | barkhan
# Processing Record 25 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 2 | bangangte
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | lavrentiya
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | zonalnoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | pak phanang
# Processing Record 39 of Set 2 | terney
# Processing Record 40 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | bathsheba
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | westport
# Processing Record 45 of Set 2 | qaqortoq
# Processing Record 46 of Set 2 | lorengau
# Processing Record 47 of Set 2 | deputatskiy
# Processing Record 48 of Set 2 | quatre cocos
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | bogale
# Processing Record 2 of Set 3 | ostrovnoy
# Processing Record 3 of Set 3 | mastic beach
# Processing Record 4 of Set 3 | sumbe
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | caravelas
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | araouane
# Processing Record 11 of Set 3 | alice springs
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 3 | nesna
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | new norfolk
# Processing Record 17 of Set 3 | luganville
# Processing Record 18 of Set 3 | kangaatsiaq
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | atuona
# Processing Record 21 of Set 3 | orange
# Processing Record 22 of Set 3 | ust-nera
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | hambantota
# Processing Record 25 of Set 3 | shenzhen
# Processing Record 26 of Set 3 | coquimbo
# Processing Record 27 of Set 3 | ketchikan
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | progreso
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | kapaa
# Processing Record 32 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 3 | balkhash
# Processing Record 34 of Set 3 | gaoua
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | jever
# Processing Record 39 of Set 3 | san pedro
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | strezhevoy
# Processing Record 42 of Set 3 | buraydah
# Processing Record 43 of Set 3 | charters towers
# Processing Record 44 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 3 | sigerfjord
# City not found. Skipping...
# Processing Record 46 of Set 3 | richards bay
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | torata
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | fort nelson
# Processing Record 2 of Set 4 | romanovskaya
# Processing Record 3 of Set 4 | nome
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | choctaw
# Processing Record 6 of Set 4 | cap malheureux
# Processing Record 7 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | kholm
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | iskateley
# Processing Record 11 of Set 4 | lazaro cardenas
# Processing Record 12 of Set 4 | ginir
# Processing Record 13 of Set 4 | mananara
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | miri
# Processing Record 17 of Set 4 | kysyl-syr
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | verkhnevilyuysk
# Processing Record 24 of Set 4 | umkomaas
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | totness
# Processing Record 27 of Set 4 | shingu
# Processing Record 28 of Set 4 | pemba
# Processing Record 29 of Set 4 | san quintin
# Processing Record 30 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 4 | dibulla
# Processing Record 32 of Set 4 | khani
# Processing Record 33 of Set 4 | sainte-maxime
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | talesh
# City not found. Skipping...
# Processing Record 36 of Set 4 | muttupet
# Processing Record 37 of Set 4 | marawi
# Processing Record 38 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 4 | nouadhibou
# Processing Record 40 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | zhezkazgan
# Processing Record 44 of Set 4 | palmerston north
# Processing Record 45 of Set 4 | guider
# Processing Record 46 of Set 4 | beringovskiy
# Processing Record 47 of Set 4 | knysna
# Processing Record 48 of Set 4 | ranong
# Processing Record 49 of Set 4 | tuatapere
# Processing Record 50 of Set 4 | gupitan
# Processing Record 1 of Set 5 | hovd
# Processing Record 2 of Set 5 | taltal
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | salalah
# Processing Record 5 of Set 5 | bontang
# Processing Record 6 of Set 5 | gazanjyk
# Processing Record 7 of Set 5 | cervo
# Processing Record 8 of Set 5 | srednekolymsk
# Processing Record 9 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 10 of Set 5 | barcelos
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | zaozerne
# Processing Record 13 of Set 5 | mehamn
# Processing Record 14 of Set 5 | thunder bay
# Processing Record 15 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 16 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 5 | juazeiro
# Processing Record 18 of Set 5 | matane
# Processing Record 19 of Set 5 | mildura
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | kroya
# Processing Record 23 of Set 5 | clovis
# Processing Record 24 of Set 5 | at-bashi
# Processing Record 25 of Set 5 | nador
# Processing Record 26 of Set 5 | plettenberg bay
# Processing Record 27 of Set 5 | pirapora
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | maltahohe
# Processing Record 30 of Set 5 | karatuzskoye
# Processing Record 31 of Set 5 | katobu
# Processing Record 32 of Set 5 | gillette
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | shirokiy
# Processing Record 35 of Set 5 | tecoanapa
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | beaverlodge
# Processing Record 38 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | carutapera
# Processing Record 41 of Set 5 | cacador
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | buluang
# Processing Record 44 of Set 5 | beira
# Processing Record 45 of Set 5 | baghmara
# Processing Record 46 of Set 5 | floro
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | fallon
# Processing Record 49 of Set 5 | kolpny
# Processing Record 50 of Set 5 | dahanu
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | halifax
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | kalur kot
# Processing Record 6 of Set 6 | yushala
# Processing Record 7 of Set 6 | nishihara
# Processing Record 8 of Set 6 | mackay
# Processing Record 9 of Set 6 | chicama
# Processing Record 10 of Set 6 | tiksi
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | port elizabeth
# Processing Record 13 of Set 6 | aleksandrov gay
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | natal
# Processing Record 16 of Set 6 | puerto carreno
# Processing Record 17 of Set 6 | sao joao da barra
# Processing Record 18 of Set 6 | khetia
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | lexington
# Processing Record 21 of Set 6 | havelock
# Processing Record 22 of Set 6 | belmonte
# Processing Record 23 of Set 6 | nemuro
# Processing Record 24 of Set 6 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 25 of Set 6 | vila
# Processing Record 26 of Set 6 | umm lajj
# Processing Record 27 of Set 6 | buncrana
# Processing Record 28 of Set 6 | tefe
# Processing Record 29 of Set 6 | sakaraha
# Processing Record 30 of Set 6 | pierre
# Processing Record 31 of Set 6 | boende
# Processing Record 32 of Set 6 | port augusta
# Processing Record 33 of Set 6 | camacha
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | mombetsu
# Processing Record 36 of Set 6 | santiago del estero
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | morgan hill
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | marsa matruh
# Processing Record 42 of Set 6 | arlit
# Processing Record 43 of Set 6 | vestmannaeyjar
# Processing Record 44 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 6 | katsuura
# Processing Record 46 of Set 6 | hay river
# Processing Record 47 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 6 | brae
# Processing Record 49 of Set 6 | khash
# Processing Record 50 of Set 6 | rocha
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | babayurt
# Processing Record 3 of Set 7 | dudinka
# Processing Record 4 of Set 7 | port shepstone
# Processing Record 5 of Set 7 | vestmanna
# Processing Record 6 of Set 7 | mahanoro
# Processing Record 7 of Set 7 | kargopol
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | ust-tsilma
# Processing Record 11 of Set 7 | mexticacan
# Processing Record 12 of Set 7 | chokurdakh
# Processing Record 13 of Set 7 | nyurba
# Processing Record 14 of Set 7 | clonakilty
# Processing Record 15 of Set 7 | lasa
# Processing Record 16 of Set 7 | nanortalik
# Processing Record 17 of Set 7 | chuy
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | poronaysk
# Processing Record 20 of Set 7 | jacmel
# Processing Record 21 of Set 7 | san vicente
# Processing Record 22 of Set 7 | santa fe
# Processing Record 23 of Set 7 | kovdor
# Processing Record 24 of Set 7 | pacific grove
# Processing Record 25 of Set 7 | humaita
# Processing Record 26 of Set 7 | newtownards
# Processing Record 27 of Set 7 | husavik
# Processing Record 28 of Set 7 | san borja
# Processing Record 29 of Set 7 | parrita
# Processing Record 30 of Set 7 | srinivaspur
# Processing Record 31 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 7 | san patricio
# Processing Record 34 of Set 7 | acapulco
# Processing Record 35 of Set 7 | guiratinga
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | puerto madryn
# Processing Record 38 of Set 7 | santiago
# Processing Record 39 of Set 7 | hanzhong
# Processing Record 40 of Set 7 | armizonskoye
# Processing Record 41 of Set 7 | nanga eboko
# Processing Record 42 of Set 7 | altay
# Processing Record 43 of Set 7 | moose factory
# Processing Record 44 of Set 7 | ilulissat
# Processing Record 45 of Set 7 | arraial do cabo
# Processing Record 46 of Set 7 | paamiut
# Processing Record 47 of Set 7 | ipatele
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | ringas
# Processing Record 50 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 8 | rabo de peixe
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | leningradskiy
# Processing Record 5 of Set 8 | candolim
# Processing Record 6 of Set 8 | kokopo
# Processing Record 7 of Set 8 | chernyshevskiy
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | acurenam
# Processing Record 10 of Set 8 | nikolskoye
# Processing Record 11 of Set 8 | pangkalanbuun
# Processing Record 12 of Set 8 | along
# Processing Record 13 of Set 8 | loralai
# Processing Record 14 of Set 8 | kavieng
# Processing Record 15 of Set 8 | kano
# Processing Record 16 of Set 8 | kukmor
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | vuktyl
# Processing Record 19 of Set 8 | arman
# Processing Record 20 of Set 8 | honiara
# Processing Record 21 of Set 8 | osmanabad
# Processing Record 22 of Set 8 | izumrud
# Processing Record 23 of Set 8 | khasan
# Processing Record 24 of Set 8 | kalmunai
# Processing Record 25 of Set 8 | mangai
# Processing Record 26 of Set 8 | ucluelet
# Processing Record 27 of Set 8 | cabedelo
# Processing Record 28 of Set 8 | yar-sale
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | karwar
# Processing Record 31 of Set 8 | bairiki
# Processing Record 32 of Set 8 | bonthe
# Processing Record 33 of Set 8 | beyneu
# Processing Record 34 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 8 | almaznyy
# Processing Record 36 of Set 8 | magadi
# Processing Record 37 of Set 8 | trairi
# Processing Record 38 of Set 8 | ballitoville
# Processing Record 39 of Set 8 | maceio
# Processing Record 40 of Set 8 | huntington
# Processing Record 41 of Set 8 | bangassou
# Processing Record 42 of Set 8 | tottori
# Processing Record 43 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 8 | samut prakan
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 8 | bati
# Processing Record 49 of Set 8 | novopavlovsk
# Processing Record 50 of Set 8 | elko
# Processing Record 1 of Set 9 | sioux lookout
# Processing Record 2 of Set 9 | gamba
# Processing Record 3 of Set 9 | sola
# Processing Record 4 of Set 9 | talara
# Processing Record 5 of Set 9 | yerbogachen
# Processing Record 6 of Set 9 | lake park
# Processing Record 7 of Set 9 | esperance
# Processing Record 8 of Set 9 | vilyuysk
# Processing Record 9 of Set 9 | itumba
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | segou
# Processing Record 12 of Set 9 | durango
# Processing Record 13 of Set 9 | palana
# Processing Record 14 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 9 | arroyo
# Processing Record 16 of Set 9 | manta
# Processing Record 17 of Set 9 | opoczno
# Processing Record 18 of Set 9 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | sinnamary
# Processing Record 20 of Set 9 | qaanaaq
# Processing Record 21 of Set 9 | weida
# Processing Record 22 of Set 9 | tsumeb
# Processing Record 23 of Set 9 | logrono
# Processing Record 24 of Set 9 | daru
# Processing Record 25 of Set 9 | huarmey
# Processing Record 26 of Set 9 | sungaipenuh
# Processing Record 27 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 28 of Set 9 | borba
# Processing Record 29 of Set 9 | port hardy
# Processing Record 30 of Set 9 | rio grande
# Processing Record 31 of Set 9 | bucerias
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | mbamba
# Processing Record 34 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 9 | shenavan
# Processing Record 36 of Set 9 | saint-pierre
# Processing Record 37 of Set 9 | antalaha
# Processing Record 38 of Set 9 | bria
# Processing Record 39 of Set 9 | paraiso
# Processing Record 40 of Set 9 | paka
# Processing Record 41 of Set 9 | lugovoy
# Processing Record 42 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 9 | port pirie
# Processing Record 44 of Set 9 | matagami
# Processing Record 45 of Set 9 | anshun
# Processing Record 46 of Set 9 | vaitape
# Processing Record 47 of Set 9 | coihaique
# Processing Record 48 of Set 9 | vila franca do campo
# Processing Record 49 of Set 9 | san joaquin
# Processing Record 50 of Set 9 | olafsvik
# Processing Record 1 of Set 10 | winnemucca
# Processing Record 2 of Set 10 | yaroslavskiy
# Processing Record 3 of Set 10 | kruisfontein
# Processing Record 4 of Set 10 | nioro
# Processing Record 5 of Set 10 | gimli
# Processing Record 6 of Set 10 | pacifica
# Processing Record 7 of Set 10 | ixtapa
# Processing Record 8 of Set 10 | fossombrone
# Processing Record 9 of Set 10 | brigantine
# Processing Record 10 of Set 10 | linxia
# Processing Record 11 of Set 10 | vanimo
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | pueblo nuevo
# Processing Record 14 of Set 10 | pital
# Processing Record 15 of Set 10 | ratnagiri
# Processing Record 16 of Set 10 | ocara
# Processing Record 17 of Set 10 | koutsouras
# Processing Record 18 of Set 10 | shenkursk
# Processing Record 19 of Set 10 | luba
# Processing Record 20 of Set 10 | byron bay
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | drexel heights
# Processing Record 23 of Set 10 | gat
# Processing Record 24 of Set 10 | znamenskoye
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | asfi
# Processing Record 27 of Set 10 | pitimbu
# Processing Record 28 of Set 10 | saint-leu
# Processing Record 29 of Set 10 | wanning
# Processing Record 30 of Set 10 | gusau
# Processing Record 31 of Set 10 | bohodukhiv
# Processing Record 32 of Set 10 | itarema
# Processing Record 33 of Set 10 | san jose
# Processing Record 34 of Set 10 | cockburn town
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | phibun mangsahan
# Processing Record 37 of Set 10 | katiola
# Processing Record 38 of Set 10 | san pablo
# Processing Record 39 of Set 10 | gornopravdinsk
# Processing Record 40 of Set 10 | warri
# Processing Record 41 of Set 10 | zhuhai
# Processing Record 42 of Set 10 | salym
# Processing Record 43 of Set 10 | oliver
# Processing Record 44 of Set 10 | stornoway
# Processing Record 45 of Set 10 | borogontsy
# Processing Record 46 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 10 | divnogorsk
# Processing Record 48 of Set 10 | te anau
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | aswan
# Processing Record 1 of Set 11 | bagdarin
# Processing Record 2 of Set 11 | marshall
# Processing Record 3 of Set 11 | adrar
# Processing Record 4 of Set 11 | gayeri
# Processing Record 5 of Set 11 | cururupu
# Processing Record 6 of Set 11 | kitimat
# Processing Record 7 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 8 of Set 11 | saravan
# Processing Record 9 of Set 11 | guanica
# Processing Record 10 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | constitucion
# Processing Record 13 of Set 11 | englewood
# Processing Record 14 of Set 11 | oranjestad
# Processing Record 15 of Set 11 | vardo
# Processing Record 16 of Set 11 | nosy varika
# Processing Record 17 of Set 11 | catalina
# Processing Record 18 of Set 11 | alindao
# Processing Record 19 of Set 11 | parkersburg
# Processing Record 20 of Set 11 | tunceli
# Processing Record 21 of Set 11 | svetlogorsk
# Processing Record 22 of Set 11 | kolyvan
# Processing Record 23 of Set 11 | carauari
# Processing Record 24 of Set 11 | tilichiki
# Processing Record 25 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 26 of Set 11 | balkanabat
# Processing Record 27 of Set 11 | sorong
# Processing Record 28 of Set 11 | medea
# Processing Record 29 of Set 11 | hamilton
# Processing Record 30 of Set 11 | tautira
# Processing Record 31 of Set 11 | bichena
# Processing Record 32 of Set 11 | mackenzie
# Processing Record 33 of Set 11 | santa cruz
# Processing Record 34 of Set 11 | surt
# Processing Record 35 of Set 11 | atocha
# Processing Record 36 of Set 11 | abrau-dyurso
# Processing Record 37 of Set 11 | chingirlau
# Processing Record 38 of Set 11 | murgasi
# City not found. Skipping...
# Processing Record 39 of Set 11 | lakatoro
# Processing Record 40 of Set 11 | los llanos de aridane
# Processing Record 41 of Set 11 | ewa beach
# Processing Record 42 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 11 | tomatlan
# Processing Record 44 of Set 11 | dunedin
# Processing Record 45 of Set 11 | hong gai
# Processing Record 46 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 11 | craig
# Processing Record 48 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 11 | ancud
# Processing Record 50 of Set 11 | cayenne
# Processing Record 1 of Set 12 | hillsborough
# Processing Record 2 of Set 12 | hvolsvollur
# Processing Record 3 of Set 12 | ayr
# Processing Record 4 of Set 12 | ulaangom
# Processing Record 5 of Set 12 | olot
# Processing Record 6 of Set 12 | sorland
# Processing Record 7 of Set 12 | takoradi
# Processing Record 8 of Set 12 | kahului
# Processing Record 9 of Set 12 | ngunguru
# Processing Record 10 of Set 12 | port hedland
# Processing Record 11 of Set 12 | bubaque
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | le port
# Processing Record 14 of Set 12 | huilong
# Processing Record 15 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 16 of Set 12 | callaway
# Processing Record 17 of Set 12 | condado
# Processing Record 18 of Set 12 | kushiro
# Processing Record 19 of Set 12 | komsomolskiy
# Processing Record 20 of Set 12 | luis correia
# Processing Record 21 of Set 12 | phaphund
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 12 | nizhniy odes
# Processing Record 25 of Set 12 | chulman
# Processing Record 26 of Set 12 | gao
# Processing Record 27 of Set 12 | kaohsiung
# Processing Record 28 of Set 12 | saint anthony
# Processing Record 29 of Set 12 | yartsevo
# Processing Record 30 of Set 12 | fenoarivo
# Processing Record 31 of Set 12 | gladstone
# Processing Record 32 of Set 12 | dalbandin
# Processing Record 33 of Set 12 | broome
# Processing Record 34 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 12 | newberry
# Processing Record 36 of Set 12 | harer
# Processing Record 37 of Set 12 | taga
# Processing Record 38 of Set 12 | aksu
# Processing Record 39 of Set 12 | mossendjo
# Processing Record 40 of Set 12 | sfantu gheorghe
# Processing Record 41 of Set 12 | garowe
# Processing Record 42 of Set 12 | carnduff
# Processing Record 43 of Set 12 | krasnovishersk
# Processing Record 44 of Set 12 | tambopata
# Processing Record 45 of Set 12 | snezhnogorsk
# Processing Record 46 of Set 12 | korla
# Processing Record 47 of Set 12 | pangody
# Processing Record 48 of Set 12 | banda aceh
# Processing Record 49 of Set 12 | kompaniyivka
# Processing Record 50 of Set 12 | weligama
# Processing Record 1 of Set 13 | laguna
# Processing Record 2 of Set 13 | mantua
# Processing Record 3 of Set 13 | azuqueca de henares
# Processing Record 4 of Set 13 | sao luis
# Processing Record 5 of Set 13 | ulan-ude
# Processing Record 6 of Set 13 | port-gentil
# Processing Record 7 of Set 13 | qui nhon
# Processing Record 8 of Set 13 | synya
# Processing Record 9 of Set 13 | igrim
# Processing Record 10 of Set 13 | lesnoy
# Processing Record 11 of Set 13 | san buenaventura
# Processing Record 12 of Set 13 | pauini
# Processing Record 13 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 13 | eureka
# Processing Record 15 of Set 13 | sharlyk
# Processing Record 16 of Set 13 | artyshta
# Processing Record 17 of Set 13 | pirgos
# Processing Record 18 of Set 13 | saint stephen
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 13 | stromness
# Processing Record 22 of Set 13 | linkoping
# Processing Record 23 of Set 13 | togur
# Processing Record 24 of Set 13 | bitung
# Processing Record 25 of Set 13 | joensuu
# Processing Record 26 of Set 13 | grand-lahou
# Processing Record 27 of Set 13 | karratha
# Processing Record 28 of Set 13 | ambilobe
# Processing Record 29 of Set 13 | wawa
# Processing Record 30 of Set 13 | praia
# Processing Record 31 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 32 of Set 13 | madang
# Processing Record 33 of Set 13 | rafaela
# Processing Record 34 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 13 | dhanwar
# Processing Record 36 of Set 13 | tolaga bay
# Processing Record 37 of Set 13 | acajutla
# Processing Record 38 of Set 13 | obo
# Processing Record 39 of Set 13 | christchurch
# Processing Record 40 of Set 13 | sibolga
# Processing Record 41 of Set 13 | kiama
# Processing Record 42 of Set 13 | roald
# Processing Record 43 of Set 13 | mabay
# Processing Record 44 of Set 13 | kuala terengganu
# Processing Record 45 of Set 13 | haines junction
# Processing Record 46 of Set 13 | novyy svit
# Processing Record 47 of Set 13 | kayseri
# Processing Record 48 of Set 13 | kumasi
# Processing Record 49 of Set 13 | ransang
# Processing Record 50 of Set 13 | harbour breton
# Processing Record 1 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 2 of Set 14 | alenquer
# Processing Record 3 of Set 14 | kibungo
# Processing Record 4 of Set 14 | mocuba
# Processing Record 5 of Set 14 | sao felix do xingu
# Processing Record 6 of Set 14 | mountain home
# Processing Record 7 of Set 14 | bichura
# Processing Record 8 of Set 14 | talnakh
# Processing Record 9 of Set 14 | sabang
# Processing Record 10 of Set 14 | vejalpur
# Processing Record 11 of Set 14 | katy
# Processing Record 12 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 14 | shenjiamen
# Processing Record 14 of Set 14 | shelburne
# Processing Record 15 of Set 14 | batemans bay
# Processing Record 16 of Set 14 | praya
# Processing Record 17 of Set 14 | sabzevar
# Processing Record 18 of Set 14 | launceston
# Processing Record 19 of Set 14 | harper
# Processing Record 20 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 14 | kismayo
# Processing Record 22 of Set 14 | kununurra
# Processing Record 23 of Set 14 | swan river
# Processing Record 24 of Set 14 | saint helens
# Processing Record 25 of Set 14 | bilibino
# Processing Record 26 of Set 14 | hofn
# Processing Record 27 of Set 14 | pemangkat
# Processing Record 28 of Set 14 | sokoni
# Processing Record 29 of Set 14 | santo domingo
# Processing Record 30 of Set 14 | buin
# Processing Record 31 of Set 14 | najran
# Processing Record 32 of Set 14 | bafilo
# Processing Record 33 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 14 | pilar
# Processing Record 35 of Set 14 | iralaya
# Processing Record 36 of Set 14 | mbouda
# Processing Record 37 of Set 14 | burla
# Processing Record 38 of Set 14 | flin flon
# Processing Record 39 of Set 14 | eregli
# Processing Record 40 of Set 14 | marsala
# Processing Record 41 of Set 14 | rodrigues alves
# Processing Record 42 of Set 14 | kashi
# Processing Record 43 of Set 14 | bilma
# Processing Record 44 of Set 14 | andenes
# Processing Record 45 of Set 14 | bonavista
# Processing Record 46 of Set 14 | key west
# Processing Record 47 of Set 14 | shihezi
# Processing Record 48 of Set 14 | sobolevo
# Processing Record 49 of Set 14 | channel-port aux basques
# Processing Record 50 of Set 14 | sitka
# Processing Record 1 of Set 15 | comodoro rivadavia
# Processing Record 2 of Set 15 | pontes e lacerda
# Processing Record 3 of Set 15 | lixourion
# Processing Record 4 of Set 15 | kenai
# Processing Record 5 of Set 15 | lima
# Processing Record 6 of Set 15 | wum
# Processing Record 7 of Set 15 | ingham
# Processing Record 8 of Set 15 | ekhabi
# Processing Record 9 of Set 15 | quelimane
# Processing Record 10 of Set 15 | ahipara
# Processing Record 11 of Set 15 | jumla
# Processing Record 12 of Set 15 | kurumkan
# Processing Record 13 of Set 15 | banamba
# Processing Record 14 of Set 15 | sambava
# Processing Record 15 of Set 15 | teya
# Processing Record 16 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 15 | flinders
# Processing Record 18 of Set 15 | goma
# Processing Record 19 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 15 | rio branco
# Processing Record 21 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 22 of Set 15 | angoche
# Processing Record 23 of Set 15 | beirut
# Processing Record 24 of Set 15 | borgarnes
# Processing Record 25 of Set 15 | orlik
# Processing Record 26 of Set 15 | lichtenburg
# Processing Record 27 of Set 15 | veraval
# Processing Record 28 of Set 15 | newport beach
# Processing Record 29 of Set 15 | grindavik
# Processing Record 30 of Set 15 | alvorada
# Processing Record 31 of Set 15 | povenets
# Processing Record 32 of Set 15 | ibra
# Processing Record 33 of Set 15 | bandarbeyla
# Processing Record 34 of Set 15 | dondo
# Processing Record 35 of Set 15 | gushikawa
# Processing Record 36 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 15 | ciudad bolivar
# Processing Record 38 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 15 | biskamzha
# Processing Record 40 of Set 15 | araceli
# Processing Record 41 of Set 15 | shimanovsk
# Processing Record 42 of Set 15 | zadar
# Processing Record 43 of Set 15 | rizal
# Processing Record 44 of Set 15 | galveston
# Processing Record 45 of Set 15 | predivinsk
# Processing Record 46 of Set 15 | alta floresta
# Processing Record 47 of Set 15 | todi
# Processing Record 48 of Set 15 | siocon
# Processing Record 49 of Set 15 | half moon bay
# Processing Record 50 of Set 15 | tongchuan
# Processing Record 1 of Set 16 | itoman
# Processing Record 2 of Set 16 | marzuq
# Processing Record 3 of Set 16 | varhaug
# Processing Record 4 of Set 16 | kerouane
# Processing Record 5 of Set 16 | tonantins
# Processing Record 6 of Set 16 | kungurtug
# Processing Record 7 of Set 16 | kropotkin
# Processing Record 8 of Set 16 | bacolod
# Processing Record 9 of Set 16 | otjiwarongo
# Processing Record 10 of Set 16 | todos santos
# Processing Record 11 of Set 16 | selma
# Processing Record 12 of Set 16 | ussuriysk
# Processing Record 13 of Set 16 | lakhdenpokhya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Rawson -43.3002  -65.1023     61.72        78         100       22.64
# 1    Carnarvon -24.8667  113.6333     87.80        62           0       10.36
# 2  Provideniya  64.3833 -173.3000     25.07        93         100       11.25
# 3      Erenhot  43.6475  111.9767     25.59        19           0       15.35
# 4       Avarua -21.2078 -159.7750     82.40        78          20        6.91
# 5     Tasiilaq  65.6145  -37.6368     24.80        54          90       26.46
# 6        Coari  -4.0850  -63.1414     74.17        91          99        2.04
# 7  San Eugenio  16.3598  120.3570     83.41        64          87        5.14
# 8        Basco  20.4487  121.9702     76.21        81          66       21.41
# 9  Yellowknife  62.4560 -114.3525      8.60        78          90        9.22
#
#   Country Current Description
# 0      AR     overcast clouds
# 1      AU           clear sky
# 2      RU          light snow
# 3      CN           clear sky
# 4      CK          few clouds
# 5      GL          light snow
# 6      BR     overcast clouds
# 7      PH     overcast clouds
# 8      PH       broken clouds
# 9      CA                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
